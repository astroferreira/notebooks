# %%
import numpy as np
from astropy import cosmology as cosmo
from astropy import units as u
from matplotlib import pyplot as plt

# %% [markdown]
# Generate a LCDM model

# %%
model = cosmo.LambdaCDM(H0=70, Om0=0.3, Ode0=0.7)
R = model.comoving_distance(np.inf)

# %% [markdown]
# Calculate Volume of the universe at z=0

# %%
V0 = 4*np.pi/3 * R**3
V0.to(u.m**3)
# Out:
# <Quantity 3.49021771e+80 m3>

# %% [markdown]
# Estimate scale factor for a range of z

# %%
zs = np.linspace(0.01, 3, 1000)
scale_factor_at_z = model.scale_factor(zs)

# %% [markdown]
# Measure volume with following distance? $$R*a$$

# %% [markdown]
# Measure volume for given z and compare to volume at z=0?

# %%
V = 4*np.pi/3 * (Ld*scale_factor_at_z)**3
plt.figure(figsize=(12,10))
plt.plot(zs, V/V0)
plt.xlabel('Redshift', fontsize=20)
plt.ylabel('V/V0', fontsize=20)
# Out:
# Text(0, 0.5, 'V/V0')
